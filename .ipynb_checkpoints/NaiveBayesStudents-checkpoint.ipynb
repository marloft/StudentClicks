# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import seaborn as sns

# The normal imports
from numpy.random import randn

# Import the stats librayr from numpy
from scipy import stats
from sklearn.naive_bayes import GaussianNB

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

train = pd.read_csv('SumStudentClicksxResult-2-0-50.csv')   # better be in the correct directory!
test = pd.read_csv('SumStudentClicksxResult-2-50-100.csv')
test.head(5)
# Out:
#    id_student  SumOfsum_click final_result
# 0      100893             250         Pass
# 1      101781             891         Pass
# 2      102806             486         Pass
# 3      102952             242         Pass
# 4     1035023             496         Pass

# %%
train.head(5)
# Out:
#    id_student  SumOfsum_click final_result
# 0      100893             206         Pass
# 1      101781            1505         Pass
# 2      102806             590         Pass
# 3      102952             444         Pass
# 4     1035023             459         Pass

# %%
cols = ['SumOfsum_click']
cols2 = ['final_result']

trainArr = train.as_matrix(cols)
trainRes = train.as_matrix(cols2)

testArr = test.as_matrix(cols)
testRes = test.as_matrix(cols2)

gnb = GaussianNB()
#print(trainArr[0])
#print(trainRes[0])
#print(testArr[0])
#print(testRes[0])

output = gnb.fit(trainArr, trainRes).predict(testArr)

for i in range(390):
    #if testRes[i][0] == output[i] and testRes[i]=="Distinction":
    #if testRes[i][0] == output[i] and testRes[i]<>"Pass":
    if testRes[i][0] == output[i]:
        #print ""
        print("PREDICTION :    " + str(output[i])) + "  " + str(testArr[i]) + "       " + str(testRes[i] + "     CORRECT")
    else:
        print(str(i) + "PREDICTION:    " + str(output[i])) + "  " + str(testArr[i]) + "       " + str(testRes[i])
# Out:
# PREDICTION :    Pass  [250]       ['Pass     CORRECT']
# PREDICTION :    Pass  [891]       ['Pass     CORRECT']
# PREDICTION :    Pass  [486]       ['Pass     CORRECT']
# PREDICTION :    Pass  [242]       ['Pass     CORRECT']
# PREDICTION :    Pass  [496]       ['Pass     CORRECT']
# PREDICTION :    Pass  [683]       ['Pass     CORRECT']
# 6PREDICTION:    Pass  [170]       ['Withdrawn']
# PREDICTION :    Pass  [82]       ['Pass     CORRECT']
# PREDICTION :    Pass  [214]       ['Pass     CORRECT']
# PREDICTION :    Pass  [473]       ['Pass     CORRECT']
# PREDICTION :    Pass  [821]       ['Pass     CORRECT']
# PREDICTION :    Pass  [971]       ['Pass     CORRECT']
# PREDICTION :    Pass  [201]       ['Pass     CORRECT']
# PREDICTION :    Pass  [168]       ['Pass     CORRECT']
# PREDICTION :    Pass  [355]       ['Pass     CORRECT']
# PREDICTION :    Pass  [431]       ['Pass     CORRECT']
# PREDICTION :    Pass  [295]       ['Pass     CORRECT']
# PREDICTION :    Pass  [118]       ['Pass     CORRECT']
# PREDICTION :    Pass  [630]       ['Pass     CORRECT']
# PREDICTION :    Pass  [377]       ['Pass     CORRECT']
# 20PREDICTION:    Pass  [1086]       ['Withdrawn']
# PREDICTION :    Pass  [94]       ['Pass     CORRECT']
# 22PREDICTION:    Pass  [671]       ['Distinction']
# PREDICTION :    Pass  [165]       ['Pass     CORRECT']
# 24PREDICTION:    Pass  [165]       ['Withdrawn']
# PREDICTION :    Pass  [70]       ['Pass     CORRECT']
# 26PREDICTION:    Pass  [70]       ['Withdrawn']
# 27PREDICTION:    Distinction  [1744]       ['Pass']
# 28PREDICTION:    Pass  [62]       ['Fail']
# PREDICTION :    Pass  [154]       ['Pass     CORRECT']
# PREDICTION :    Pass  [451]       ['Pass     CORRECT']
# PREDICTION :    Pass  [136]       ['Pass     CORRECT']
# 32PREDICTION:    Pass  [136]       ['Withdrawn']
# 33PREDICTION:    Pass  [457]       ['Fail']
# PREDICTION :    Pass  [440]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1307]       ['Pass     CORRECT']
# PREDICTION :    Pass  [55]       ['Pass     CORRECT']
# 37PREDICTION:    Pass  [288]       ['Fail']
# PREDICTION :    Pass  [878]       ['Pass     CORRECT']
# 39PREDICTION:    Pass  [159]       ['Fail']
# PREDICTION :    Pass  [159]       ['Pass     CORRECT']
# 41PREDICTION:    Pass  [80]       ['Fail']
# PREDICTION :    Pass  [80]       ['Pass     CORRECT']
# 43PREDICTION:    Pass  [45]       ['Withdrawn']
# PREDICTION :    Pass  [800]       ['Pass     CORRECT']
# PREDICTION :    Pass  [593]       ['Pass     CORRECT']
# 46PREDICTION:    Pass  [593]       ['Withdrawn']
# PREDICTION :    Pass  [29]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1104]       ['Pass     CORRECT']
# PREDICTION :    Pass  [382]       ['Pass     CORRECT']
# PREDICTION :    Pass  [859]       ['Pass     CORRECT']
# PREDICTION :    Pass  [241]       ['Pass     CORRECT']
# 52PREDICTION:    Pass  [241]       ['Withdrawn']
# PREDICTION :    Pass  [398]       ['Pass     CORRECT']
# 54PREDICTION:    Pass  [1218]       ['Withdrawn']
# PREDICTION :    Pass  [274]       ['Pass     CORRECT']
# 56PREDICTION:    Pass  [150]       ['Fail']
# 57PREDICTION:    Pass  [1696]       ['Distinction']
# PREDICTION :    Pass  [1481]       ['Pass     CORRECT']
# PREDICTION :    Pass  [138]       ['Pass     CORRECT']
# PREDICTION :    Pass  [398]       ['Pass     CORRECT']
# PREDICTION :    Pass  [120]       ['Pass     CORRECT']
# PREDICTION :    Pass  [358]       ['Pass     CORRECT']
# PREDICTION :    Pass  [200]       ['Pass     CORRECT']
# PREDICTION :    Pass  [554]       ['Pass     CORRECT']
# PREDICTION :    Pass  [733]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1520]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1296]       ['Pass     CORRECT']
# 68PREDICTION:    Pass  [1239]       ['Withdrawn']
# PREDICTION :    Pass  [763]       ['Pass     CORRECT']
# 70PREDICTION:    Pass  [14]       ['Fail']
# PREDICTION :    Pass  [1616]       ['Pass     CORRECT']
# PREDICTION :    Pass  [314]       ['Pass     CORRECT']
# PREDICTION :    Pass  [125]       ['Pass     CORRECT']
# PREDICTION :    Pass  [412]       ['Pass     CORRECT']
# 75PREDICTION:    Pass  [48]       ['Withdrawn']
# PREDICTION :    Pass  [383]       ['Pass     CORRECT']
# PREDICTION :    Pass  [183]       ['Pass     CORRECT']
# PREDICTION :    Pass  [385]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1508]       ['Pass     CORRECT']
# 80PREDICTION:    Pass  [122]       ['Fail']
# PREDICTION :    Pass  [1541]       ['Pass     CORRECT']
# PREDICTION :    Pass  [523]       ['Pass     CORRECT']
# PREDICTION :    Distinction  [1829]       ['Distinction     CORRECT']
# PREDICTION :    Pass  [430]       ['Pass     CORRECT']
# 85PREDICTION:    Pass  [430]       ['Withdrawn']
# PREDICTION :    Pass  [467]       ['Pass     CORRECT']
# PREDICTION :    Pass  [191]       ['Pass     CORRECT']
# PREDICTION :    Pass  [532]       ['Pass     CORRECT']
# PREDICTION :    Pass  [301]       ['Pass     CORRECT']
# PREDICTION :    Pass  [701]       ['Pass     CORRECT']
# PREDICTION :    Pass  [404]       ['Pass     CORRECT']
# PREDICTION :    Pass  [71]       ['Pass     CORRECT']
# 93PREDICTION:    Pass  [768]       ['Withdrawn']
# 94PREDICTION:    Distinction  [3754]       ['Pass']
# 95PREDICTION:    Distinction  [3754]       ['Withdrawn']
# PREDICTION :    Pass  [250]       ['Pass     CORRECT']
# PREDICTION :    Pass  [89]       ['Pass     CORRECT']
# PREDICTION :    Pass  [232]       ['Pass     CORRECT']
# PREDICTION :    Pass  [39]       ['Pass     CORRECT']
# 100PREDICTION:    Pass  [428]       ['Withdrawn']
# PREDICTION :    Pass  [507]       ['Pass     CORRECT']
# PREDICTION :    Pass  [420]       ['Pass     CORRECT']
# 103PREDICTION:    Pass  [47]       ['Fail']
# 104PREDICTION:    Pass  [734]       ['Fail']
# 105PREDICTION:    Pass  [1396]       ['Withdrawn']
# 106PREDICTION:    Pass  [287]       ['Fail']
# 107PREDICTION:    Pass  [287]       ['Withdrawn']
# PREDICTION :    Pass  [305]       ['Pass     CORRECT']
# PREDICTION :    Pass  [100]       ['Pass     CORRECT']
# 110PREDICTION:    Pass  [479]       ['Fail']
# PREDICTION :    Pass  [160]       ['Pass     CORRECT']
# 112PREDICTION:    Pass  [1113]       ['Distinction']
# PREDICTION :    Pass  [568]       ['Pass     CORRECT']
# 114PREDICTION:    Pass  [568]       ['Withdrawn']
# PREDICTION :    Pass  [486]       ['Pass     CORRECT']
# PREDICTION :    Pass  [589]       ['Pass     CORRECT']
# PREDICTION :    Pass  [910]       ['Pass     CORRECT']
# PREDICTION :    Pass  [250]       ['Pass     CORRECT']
# 119PREDICTION:    Pass  [45]       ['Fail']
# PREDICTION :    Pass  [422]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1106]       ['Pass     CORRECT']
# PREDICTION :    Pass  [307]       ['Pass     CORRECT']
# PREDICTION :    Pass  [446]       ['Pass     CORRECT']
# PREDICTION :    Pass  [311]       ['Pass     CORRECT']
# PREDICTION :    Pass  [585]       ['Pass     CORRECT']
# 126PREDICTION:    Pass  [873]       ['Withdrawn']
# PREDICTION :    Pass  [473]       ['Pass     CORRECT']
# 128PREDICTION:    Pass  [594]       ['Distinction']
# 129PREDICTION:    Pass  [409]       ['Fail']
# PREDICTION :    Pass  [39]       ['Pass     CORRECT']
# PREDICTION :    Pass  [56]       ['Pass     CORRECT']
# PREDICTION :    Pass  [203]       ['Pass     CORRECT']
# PREDICTION :    Pass  [191]       ['Pass     CORRECT']
# PREDICTION :    Pass  [285]       ['Pass     CORRECT']
# PREDICTION :    Pass  [30]       ['Pass     CORRECT']
# 136PREDICTION:    Pass  [509]       ['Withdrawn']
# PREDICTION :    Pass  [690]       ['Pass     CORRECT']
# PREDICTION :    Pass  [89]       ['Pass     CORRECT']
# 139PREDICTION:    Pass  [211]       ['Distinction']
# 140PREDICTION:    Pass  [351]       ['Fail']
# 141PREDICTION:    Pass  [110]       ['Fail']
# PREDICTION :    Pass  [11]       ['Pass     CORRECT']
# 143PREDICTION:    Pass  [11]       ['Withdrawn']
# 144PREDICTION:    Pass  [406]       ['Fail']
# PREDICTION :    Pass  [61]       ['Pass     CORRECT']
# 146PREDICTION:    Pass  [61]       ['Withdrawn']
# PREDICTION :    Pass  [67]       ['Pass     CORRECT']
# 148PREDICTION:    Distinction  [2127]       ['Pass']
# PREDICTION :    Pass  [523]       ['Pass     CORRECT']
# PREDICTION :    Pass  [565]       ['Pass     CORRECT']
# PREDICTION :    Pass  [162]       ['Pass     CORRECT']
# PREDICTION :    Pass  [382]       ['Pass     CORRECT']
# 153PREDICTION:    Pass  [329]       ['Withdrawn']
# PREDICTION :    Pass  [63]       ['Pass     CORRECT']
# PREDICTION :    Pass  [107]       ['Pass     CORRECT']
# 156PREDICTION:    Pass  [79]       ['Fail']
# 157PREDICTION:    Pass  [217]       ['Withdrawn']
# 158PREDICTION:    Pass  [1019]       ['Distinction']
# PREDICTION :    Pass  [753]       ['Pass     CORRECT']
# PREDICTION :    Pass  [496]       ['Pass     CORRECT']
# 161PREDICTION:    Pass  [401]       ['Fail']
# PREDICTION :    Pass  [37]       ['Pass     CORRECT']
# 163PREDICTION:    Pass  [136]       ['Fail']
# 164PREDICTION:    Pass  [136]       ['Withdrawn']
# PREDICTION :    Pass  [610]       ['Pass     CORRECT']
# PREDICTION :    Pass  [126]       ['Pass     CORRECT']
# 167PREDICTION:    Pass  [33]       ['Fail']
# PREDICTION :    Pass  [616]       ['Pass     CORRECT']
# PREDICTION :    Pass  [942]       ['Pass     CORRECT']
# PREDICTION :    Pass  [739]       ['Pass     CORRECT']
# 171PREDICTION:    Pass  [420]       ['Fail']
# PREDICTION :    Pass  [227]       ['Pass     CORRECT']
# 173PREDICTION:    Pass  [277]       ['Fail']
# 174PREDICTION:    Pass  [889]       ['Fail']
# 175PREDICTION:    Pass  [889]       ['Withdrawn']
# PREDICTION :    Pass  [81]       ['Pass     CORRECT']
# PREDICTION :    Pass  [431]       ['Pass     CORRECT']
# PREDICTION :    Pass  [437]       ['Pass     CORRECT']
# PREDICTION :    Pass  [677]       ['Pass     CORRECT']
# PREDICTION :    Pass  [599]       ['Pass     CORRECT']
# PREDICTION :    Pass  [413]       ['Pass     CORRECT']
# PREDICTION :    Pass  [632]       ['Pass     CORRECT']
# PREDICTION :    Pass  [461]       ['Pass     CORRECT']
# PREDICTION :    Pass  [130]       ['Pass     CORRECT']
# PREDICTION :    Pass  [127]       ['Pass     CORRECT']
# PREDICTION :    Pass  [229]       ['Pass     CORRECT']
# PREDICTION :    Pass  [197]       ['Pass     CORRECT']
# 188PREDICTION:    Pass  [225]       ['Distinction']
# PREDICTION :    Pass  [823]       ['Pass     CORRECT']
# PREDICTION :    Pass  [240]       ['Pass     CORRECT']
# 191PREDICTION:    Pass  [62]       ['Withdrawn']
# PREDICTION :    Pass  [1064]       ['Pass     CORRECT']
# PREDICTION :    Pass  [660]       ['Pass     CORRECT']
# 194PREDICTION:    Distinction  [1994]       ['Pass']
# PREDICTION :    Pass  [131]       ['Pass     CORRECT']
# PREDICTION :    Pass  [269]       ['Pass     CORRECT']
# PREDICTION :    Pass  [283]       ['Pass     CORRECT']
# PREDICTION :    Pass  [317]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1]       ['Pass     CORRECT']
# 200PREDICTION:    Pass  [1]       ['Withdrawn']
# PREDICTION :    Pass  [344]       ['Pass     CORRECT']
# PREDICTION :    Pass  [642]       ['Pass     CORRECT']
# 203PREDICTION:    Pass  [1]       ['Fail']
# 204PREDICTION:    Pass  [1]       ['Withdrawn']
# PREDICTION :    Pass  [409]       ['Pass     CORRECT']
# PREDICTION :    Pass  [215]       ['Pass     CORRECT']
# PREDICTION :    Pass  [772]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1400]       ['Pass     CORRECT']
# PREDICTION :    Pass  [269]       ['Pass     CORRECT']
# PREDICTION :    Pass  [405]       ['Pass     CORRECT']
# PREDICTION :    Pass  [193]       ['Pass     CORRECT']
# PREDICTION :    Pass  [173]       ['Pass     CORRECT']
# 213PREDICTION:    Pass  [280]       ['Withdrawn']
# PREDICTION :    Pass  [68]       ['Pass     CORRECT']
# PREDICTION :    Pass  [422]       ['Pass     CORRECT']
# PREDICTION :    Pass  [198]       ['Pass     CORRECT']
# PREDICTION :    Pass  [246]       ['Pass     CORRECT']
# PREDICTION :    Pass  [718]       ['Pass     CORRECT']
# PREDICTION :    Pass  [158]       ['Pass     CORRECT']
# PREDICTION :    Pass  [603]       ['Pass     CORRECT']
# PREDICTION :    Pass  [552]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1178]       ['Pass     CORRECT']
# PREDICTION :    Pass  [371]       ['Pass     CORRECT']
# PREDICTION :    Pass  [350]       ['Pass     CORRECT']
# 225PREDICTION:    Pass  [1701]       ['Distinction']
# PREDICTION :    Pass  [143]       ['Pass     CORRECT']
# PREDICTION :    Pass  [218]       ['Pass     CORRECT']
# PREDICTION :    Pass  [97]       ['Pass     CORRECT']
# 229PREDICTION:    Pass  [99]       ['Fail']
# PREDICTION :    Pass  [849]       ['Pass     CORRECT']
# 231PREDICTION:    Pass  [148]       ['Fail']
# PREDICTION :    Pass  [395]       ['Pass     CORRECT']
# 233PREDICTION:    Pass  [764]       ['Fail']
# PREDICTION :    Pass  [463]       ['Pass     CORRECT']
# 235PREDICTION:    Pass  [1]       ['Fail']
# 236PREDICTION:    Pass  [1]       ['Withdrawn']
# PREDICTION :    Pass  [16]       ['Pass     CORRECT']
# 238PREDICTION:    Pass  [1192]       ['Distinction']
# 239PREDICTION:    Pass  [661]       ['Distinction']
# PREDICTION :    Pass  [146]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1230]       ['Pass     CORRECT']
# PREDICTION :    Pass  [236]       ['Pass     CORRECT']
# PREDICTION :    Pass  [968]       ['Pass     CORRECT']
# 244PREDICTION:    Pass  [988]       ['Withdrawn']
# 245PREDICTION:    Pass  [250]       ['Distinction']
# PREDICTION :    Pass  [119]       ['Pass     CORRECT']
# 247PREDICTION:    Pass  [16]       ['Fail']
# 248PREDICTION:    Pass  [5]       ['Fail']
# PREDICTION :    Pass  [503]       ['Pass     CORRECT']
# PREDICTION :    Pass  [271]       ['Pass     CORRECT']
# PREDICTION :    Pass  [450]       ['Pass     CORRECT']
# PREDICTION :    Pass  [158]       ['Pass     CORRECT']
# PREDICTION :    Pass  [481]       ['Pass     CORRECT']
# PREDICTION :    Pass  [115]       ['Pass     CORRECT']
# 255PREDICTION:    Pass  [1642]       ['Distinction']
# PREDICTION :    Pass  [41]       ['Pass     CORRECT']
# PREDICTION :    Pass  [444]       ['Pass     CORRECT']
# PREDICTION :    Pass  [246]       ['Pass     CORRECT']
# 259PREDICTION:    Pass  [280]       ['Fail']
# PREDICTION :    Pass  [280]       ['Pass     CORRECT']
# 261PREDICTION:    Pass  [679]       ['Distinction']
# PREDICTION :    Pass  [96]       ['Pass     CORRECT']
# PREDICTION :    Pass  [312]       ['Pass     CORRECT']
# 264PREDICTION:    Pass  [341]       ['Fail']
# 265PREDICTION:    Pass  [12]       ['Fail']
# PREDICTION :    Pass  [204]       ['Pass     CORRECT']
# PREDICTION :    Pass  [270]       ['Pass     CORRECT']
# PREDICTION :    Pass  [324]       ['Pass     CORRECT']
# PREDICTION :    Pass  [880]       ['Pass     CORRECT']
# PREDICTION :    Pass  [286]       ['Pass     CORRECT']
# PREDICTION :    Pass  [464]       ['Pass     CORRECT']
# PREDICTION :    Pass  [838]       ['Pass     CORRECT']
# PREDICTION :    Distinction  [3478]       ['Distinction     CORRECT']
# PREDICTION :    Pass  [88]       ['Pass     CORRECT']
# PREDICTION :    Pass  [663]       ['Pass     CORRECT']
# PREDICTION :    Pass  [440]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1250]       ['Pass     CORRECT']
# 278PREDICTION:    Distinction  [3076]       ['Pass']
# PREDICTION :    Pass  [506]       ['Pass     CORRECT']
# PREDICTION :    Pass  [554]       ['Pass     CORRECT']
# PREDICTION :    Pass  [25]       ['Pass     CORRECT']
# PREDICTION :    Pass  [162]       ['Pass     CORRECT']
# 283PREDICTION:    Pass  [620]       ['Distinction']
# 284PREDICTION:    Pass  [620]       ['Withdrawn']
# PREDICTION :    Pass  [396]       ['Pass     CORRECT']
# PREDICTION :    Pass  [46]       ['Pass     CORRECT']
# PREDICTION :    Pass  [95]       ['Pass     CORRECT']
# 288PREDICTION:    Pass  [21]       ['Fail']
# 289PREDICTION:    Pass  [51]       ['Withdrawn']
# PREDICTION :    Pass  [885]       ['Pass     CORRECT']
# 291PREDICTION:    Pass  [885]       ['Withdrawn']
# PREDICTION :    Pass  [365]       ['Pass     CORRECT']
# PREDICTION :    Pass  [101]       ['Pass     CORRECT']
# 294PREDICTION:    Pass  [66]       ['Fail']
# PREDICTION :    Pass  [101]       ['Pass     CORRECT']
# 296PREDICTION:    Pass  [101]       ['Withdrawn']
# PREDICTION :    Pass  [513]       ['Pass     CORRECT']
# PREDICTION :    Pass  [206]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1531]       ['Pass     CORRECT']
# 300PREDICTION:    Pass  [10]       ['Fail']
# PREDICTION :    Pass  [228]       ['Pass     CORRECT']
# 302PREDICTION:    Pass  [670]       ['Distinction']
# PREDICTION :    Pass  [162]       ['Pass     CORRECT']
# 304PREDICTION:    Pass  [58]       ['Fail']
# PREDICTION :    Pass  [191]       ['Pass     CORRECT']
# 306PREDICTION:    Pass  [100]       ['Fail']
# 307PREDICTION:    Pass  [258]       ['Fail']
# PREDICTION :    Pass  [202]       ['Pass     CORRECT']
# PREDICTION :    Pass  [624]       ['Pass     CORRECT']
# PREDICTION :    Pass  [485]       ['Pass     CORRECT']
# PREDICTION :    Pass  [143]       ['Pass     CORRECT']
# 312PREDICTION:    Pass  [41]       ['Fail']
# PREDICTION :    Pass  [203]       ['Pass     CORRECT']
# 314PREDICTION:    Pass  [320]       ['Distinction']
# PREDICTION :    Pass  [634]       ['Pass     CORRECT']
# PREDICTION :    Pass  [464]       ['Pass     CORRECT']
# PREDICTION :    Pass  [281]       ['Pass     CORRECT']
# PREDICTION :    Pass  [147]       ['Pass     CORRECT']
# PREDICTION :    Pass  [57]       ['Pass     CORRECT']
# PREDICTION :    Pass  [231]       ['Pass     CORRECT']
# PREDICTION :    Pass  [80]       ['Pass     CORRECT']
# PREDICTION :    Pass  [176]       ['Pass     CORRECT']
# PREDICTION :    Pass  [125]       ['Pass     CORRECT']
# 324PREDICTION:    Pass  [125]       ['Withdrawn']
# 325PREDICTION:    Pass  [74]       ['Fail']
# PREDICTION :    Pass  [479]       ['Pass     CORRECT']
# PREDICTION :    Pass  [189]       ['Pass     CORRECT']
# PREDICTION :    Pass  [208]       ['Pass     CORRECT']
# 329PREDICTION:    Pass  [345]       ['Fail']
# PREDICTION :    Pass  [166]       ['Pass     CORRECT']
# PREDICTION :    Pass  [570]       ['Pass     CORRECT']
# PREDICTION :    Pass  [104]       ['Pass     CORRECT']
# PREDICTION :    Pass  [201]       ['Pass     CORRECT']
# PREDICTION :    Pass  [124]       ['Pass     CORRECT']
# 335PREDICTION:    Pass  [272]       ['Fail']
# 336PREDICTION:    Pass  [272]       ['Withdrawn']
# 337PREDICTION:    Pass  [158]       ['Fail']
# PREDICTION :    Pass  [64]       ['Pass     CORRECT']
# PREDICTION :    Pass  [73]       ['Pass     CORRECT']
# PREDICTION :    Pass  [96]       ['Pass     CORRECT']
# 341PREDICTION:    Pass  [351]       ['Withdrawn']
# 342PREDICTION:    Pass  [393]       ['Distinction']
# PREDICTION :    Pass  [161]       ['Pass     CORRECT']
# PREDICTION :    Pass  [325]       ['Pass     CORRECT']
# 345PREDICTION:    Pass  [138]       ['Withdrawn']
# PREDICTION :    Pass  [442]       ['Pass     CORRECT']
# PREDICTION :    Pass  [359]       ['Pass     CORRECT']
# PREDICTION :    Pass  [249]       ['Pass     CORRECT']
# PREDICTION :    Pass  [216]       ['Pass     CORRECT']
# PREDICTION :    Pass  [194]       ['Pass     CORRECT']
# PREDICTION :    Pass  [597]       ['Pass     CORRECT']
# PREDICTION :    Pass  [1004]       ['Pass     CORRECT']
# PREDICTION :    Pass  [549]       ['Pass     CORRECT']
# PREDICTION :    Pass  [214]       ['Pass     CORRECT']
# 355PREDICTION:    Pass  [29]       ['Fail']
# 356PREDICTION:    Pass  [146]       ['Withdrawn']
# PREDICTION :    Pass  [132]       ['Pass     CORRECT']
# PREDICTION :    Pass  [340]       ['Pass     CORRECT']
# PREDICTION :    Pass  [335]       ['Pass     CORRECT']
# 360PREDICTION:    Pass  [26]       ['Fail']
# PREDICTION :    Pass  [467]       ['Pass     CORRECT']
# 362PREDICTION:    Distinction  [1889]       ['Pass']
# PREDICTION :    Pass  [123]       ['Pass     CORRECT']
# PREDICTION :    Pass  [191]       ['Pass     CORRECT']
# 365PREDICTION:    Pass  [444]       ['Withdrawn']
# 366PREDICTION:    Pass  [98]       ['Fail']
# PREDICTION :    Pass  [1099]       ['Pass     CORRECT']
# PREDICTION :    Pass  [717]       ['Pass     CORRECT']
# 369PREDICTION:    Pass  [77]       ['Fail']
# 370PREDICTION:    Pass  [77]       ['Withdrawn']
# PREDICTION :    Pass  [679]       ['Pass     CORRECT']
# PREDICTION :    Pass  [241]       ['Pass     CORRECT']
# 373PREDICTION:    Pass  [1353]       ['Distinction']
# PREDICTION :    Pass  [533]       ['Pass     CORRECT']
# 375PREDICTION:    Pass  [41]       ['Fail']
# PREDICTION :    Pass  [1004]       ['Pass     CORRECT']
# PREDICTION :    Pass  [590]       ['Pass     CORRECT']
# PREDICTION :    Distinction  [2401]       ['Distinction     CORRECT']
# PREDICTION :    Pass  [170]       ['Pass     CORRECT']
# PREDICTION :    Pass  [837]       ['Pass     CORRECT']
# PREDICTION :    Pass  [440]       ['Pass     CORRECT']
# PREDICTION :    Pass  [45]       ['Pass     CORRECT']
# 383PREDICTION:    Pass  [45]       ['Withdrawn']
# PREDICTION :    Pass  [455]       ['Pass     CORRECT']
# PREDICTION :    Pass  [388]       ['Pass     CORRECT']
# PREDICTION :    Pass  [262]       ['Pass     CORRECT']
# 387PREDICTION:    Pass  [816]       ['Withdrawn']
# PREDICTION :    Pass  [606]       ['Pass     CORRECT']
# 389PREDICTION:    Distinction  [1881]       ['Pass']
# /Users/maryl/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
correct = 0.0

for i in range(len(output)): 
    if testRes[i][0] == output[i]: 
        correct += 1
    
print(correct / len(output))


#print("Accuracy: " + gnb.score(testArr, testRes))
print("Accuracy: " + str(gnb.score(testArr, testRes)))
# Out:
# 0.693094629156
# Accuracy: 0.693094629156

# %%
count=0 
passn=0
fail=0
distinction=0
withdrawn=0
for i in range(len(output)): 
    count += 1
    if testRes[i][0]=='Pass':
        passn += 1
    if testRes[i][0]=='Fail':
        fail += 1
    if testRes[i][0]=='Distinction':
        distinction += 1
    if testRes[i][0]=='Withdrawn':
        withdrawn += 1
print ("Pass: " + str(passn))
print ("Fail: " + str(fail))
print ("Distinction: " + str(distinction))
print ("Withdrawn: " + str(withdrawn))
# Out:
# Pass: 275
# Fail: 50
# Distinction: 21
# Withdrawn: 45

# %%
plt.hist(testArr)
# Out:
# (array([ 216.,  109.,   35.,   12.,   10.,    4.,    1.,    0.,    1.,    3.]),
#  array([  1.00000000e+00,   3.76300000e+02,   7.51600000e+02,
#           1.12690000e+03,   1.50220000e+03,   1.87750000e+03,
#           2.25280000e+03,   2.62810000e+03,   3.00340000e+03,
#           3.37870000e+03,   3.75400000e+03]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(testArr, normed=True,color='indianred',alpha=0.5,bins=20)
#plt.hist(output, normed=True,alpha=0.5,bins=20)
# Out:
# (array([  1.73092557e-03,   1.21301084e-03,   9.40424131e-04,
#           5.45173409e-04,   2.99845375e-04,   1.77181358e-04,
#           1.09034682e-04,   5.45173409e-05,   8.17760114e-05,
#           5.45173409e-05,   4.08880057e-05,   1.36293352e-05,
#           1.36293352e-05,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.36293352e-05,   0.00000000e+00,
#           1.36293352e-05,   2.72586705e-05]),
#  array([  1.00000000e+00,   1.88650000e+02,   3.76300000e+02,
#           5.63950000e+02,   7.51600000e+02,   9.39250000e+02,
#           1.12690000e+03,   1.31455000e+03,   1.50220000e+03,
#           1.68985000e+03,   1.87750000e+03,   2.06515000e+03,
#           2.25280000e+03,   2.44045000e+03,   2.62810000e+03,
#           2.81575000e+03,   3.00340000e+03,   3.19105000e+03,
#           3.37870000e+03,   3.56635000e+03,   3.75400000e+03]),
#  <a list of 20 Patch objects>)

# %%
sns.distplot(testArr,bins=25,
            kde_kws={'color':'indianred','label':'KDE PLOT'},
            hist_kws={'color':'blue','label':"HIST"})

# %%
plt.hist(testArr, normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(trainArr, normed=True,alpha=0.5,bins=20)
# Out:
# (array([  1.00707647e-03,   1.41693317e-03,   8.19713405e-04,
#           5.73799383e-04,   3.27885362e-04,   2.45914021e-04,
#           5.85509575e-05,   9.36815320e-05,   5.85509575e-05,
#           1.17101915e-05,   3.51305745e-05,   1.17101915e-05,
#           0.00000000e+00,   1.17101915e-05,   0.00000000e+00,
#           3.51305745e-05,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.17101915e-05]),
#  array([    7. ,   218.9,   430.8,   642.7,   854.6,  1066.5,  1278.4,
#          1490.3,  1702.2,  1914.1,  2126. ,  2337.9,  2549.8,  2761.7,
#          2973.6,  3185.5,  3397.4,  3609.3,  3821.2,  4033.1,  4245. ]),
#  <a list of 20 Patch objects>)

# %%
sns.heatmap(testArr)
